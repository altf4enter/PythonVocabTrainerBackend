# %%
import inspect
print(inspect.getsourcefile(imageio.plugins.pillowmulti))
# Out:
# C:\Users\helen\Anaconda3\lib\site-packages\imageio\plugins\pillowmulti.py

# %%
import imageio
help("imageio.plugins.pillowmulti")
#i m a g e i o . p l u g i n s . p i l l o w m u l t i . i m a g e i o . p l u g i n s . p i l l o w m u l t i
# Out:
# Help on module imageio.plugins.pillowmulti in imageio.plugins:
#
# NAME
#     imageio.plugins.pillowmulti - PIL formats for multiple images.
#
# CLASSES
#     builtins.object
#         GifWriter
#     imageio.plugins.pillow.PillowFormat(imageio.core.format.Format)
#         GIFFormat
#         TIFFFormat
#
#     class GIFFormat(imageio.plugins.pillow.PillowFormat)
#      |  GIFFormat(*args, **kwargs)
#      |
#      |  A format for reading and writing static and animated GIF, based
#      |  on Pillow.
#      |
#      |  Images read with this format are always RGBA. Currently,
#      |  the alpha channel is ignored when saving RGB images with this
#      |  format.
#      |
#      |  Parameters for reading
#      |  ----------------------
#      |  None
#      |
#      |  Parameters for saving
#      |  ---------------------
#      |  loop : int
#      |      The number of iterations. Default 0 (meaning loop indefinitely).
#      |  duration : {float, list}
# ...

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -------------------
# alabaster                          0.7.12
# anaconda-client                    1.7.2
# anaconda-navigator                 2.0.3
# anaconda-project                   0.9.1
# anyio                              2.2.0
# anytree                            2.8.0
# appdirs                            1.4.4
# argh                               0.26.2
# argon2-cffi                        20.1.0
# asn1crypto                         1.4.0
# astroid                            2.5
# astropy                            4.2.1
# async-generator                    1.10
# atomicwrites                       1.4.0
# attrs                              20.3.0
# audioread                          2.1.9
# autopep8                           1.5.6
# Babel                              2.9.0
# backcall                           0.2.0
# backports.functools-lru-cache      1.6.4
# ...

# %%
import os
os.listdir(folder)
# Out:
# ['ijson.items.txt',
#  'ijson.items_solution.json',
#  'ijson.parse.txt',
#  'ijson.parse_solution.json',
#  'librosa.display.specshow.txt',
#  'librosa.display.specshow_solution.json',
#  'librosa.feature.melspectrogram.txt',
#  'librosa.feature.melspectrogram_solution.json',
#  'librosa.filters.wavelet.txt',
#  'librosa.filters.wavelet_solution.json',
#  'matplotlib.pyplot.plt.json',
#  'matplotlib.pyplot.plt.txt',
#  'matplotlib.pyplot.scatter.txt',
#  'matplotlib.pyplot.scatter_solution.json',
#  'nltk.parse.malt.find_malt_model.txt',
#  'nltk.parse.malt.malt_regex_tagger.txt',
#  'nltk.pos_tag.txt',
#  'nltk.word_tokenize.txt',
#  'numpy.fft.fft.txt',
#  'numpy.fft.irfft2.txt',
#  'numpy.mean.txt',
#  'pd.DataFrame.describe.txt',
#  'pd.DataFrame.head.txt',
#  'pd.DataFrame.loc.txt',
#  'pd.DataFrame.sort_values.txt',
#  're.compile.txt',
#  're.findall.txt',
#  're.match.txt',
#  're.search.txt',
#  'requests.get.txt',
#  'scipy.signal.convolve.txt',
# ...

# %%
import anytree
help(anytree.Node)
# Out:
# Help on class Node in module anytree.node.node:
#
# class Node(anytree.node.nodemixin.NodeMixin, builtins.object)
#  |  Node(name, parent=None, children=None, **kwargs)
#  |
#  |  Method resolution order:
#  |      Node
#  |      anytree.node.nodemixin.NodeMixin
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, parent=None, children=None, **kwargs)
#  |      A simple tree node with a `name` and any `kwargs`.
#  |
#  |      Args:
#  |          name: A name or any other object this node can reference to as idendifier.
#  |
#  |      Keyword Args:
#  |          parent: Reference to parent node.
#  |          children: Iterable with child nodes.
#  |          *: Any other given attribute is just stored as object attribute.
#  |
#  |      Other than :any:`AnyNode` this class has at least the `name` attribute,
#  |      to distinguish between different instances.
#  |
#  |      The `parent` attribute refers the parent node:
#  |
# ...

# %%
# %%capture text
import matplotlib.pyplot as plt
filetype = "classes"
folder = f"raw_help_texts/{filetype}/"
help(plt.scatter)

# %%
f = open(f"{folder}/{classname}.txt", "w", encoding="utf-8")
f.write(str(text))
f.close()

# %%
import nltk
import numpy
help(nltk.word_tokenize)
# Out:
# Help on function word_tokenize in module nltk.tokenize:
#
# word_tokenize(text, language='english', preserve_line=False)
#     Return a tokenized copy of *text*,
#     using NLTK's recommended word tokenizer
#     (currently an improved :class:`.TreebankWordTokenizer`
#     along with :class:`.PunktSentenceTokenizer`
#     for the specified language).
#
#     :param text: text to split into words
#     :type text: str
#     :param language: the model name in the Punkt corpus
#     :type language: str
#     :param preserve_line: An option to keep the preserve the sentence and not sentence tokenize it.
#     :type preserve_line: bool
